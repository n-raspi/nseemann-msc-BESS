# %%
import pandas as pd
pd.options.plotting.backend = "plotly"

# %%
load_20 = pd.read_csv('../../20_data/load_profiles_braeuer/LoadProfile_20IPs_2016.csv', delimiter = ';', skiprows=1)
load_30 = pd.read_csv('../../20_data/load_profiles_braeuer/LoadProfile_30IPs_2017.csv', delimiter = ';', skiprows=1)

# %%
#load_30['Time stamp'] = pd.to_datetime(load_20['Time stamp'], format = "%d.%m.%Y %H:%M:%S")
#print(load_30.index[28908])
#load_30.drop([28908, inplace=True)
#load_30['Time stamp'] = pd.to_datetime(load_30['Time stamp'], format = "%d.%m.%Y %H:%M:%S")
load_30 = pd.read_csv('../../20_data/load_profiles_braeuer/LoadProfile_30IPs_2017.csv', delimiter = ';', skiprows=1)
load_30.dropna(how='any', inplace = True)
load_30['Time stamp'] = load_30['Time stamp'].apply(lambda x: x.strip('b '))
load_30['Time stamp'] = pd.to_datetime(load_30['Time stamp'], format = "%d.%m.%Y %H:%M:%S")
load_30.set_index('Time stamp', inplace = True)
ax = load_30.plot(legend=False)
ax.set_xlim(pd.Timestamp('2017-02-15'), pd.Timestamp('2017-02-16'))
#ax.set_ylim(0,10)
# Out:
# (np.float64(17212.0), np.float64(17213.0))

# %%
load_20.dropna(how='any', inplace = True)
load_20['Time stamp'] = load_20['Time stamp'].apply(lambda x: x.strip('b '))
load_20['Time stamp'] = pd.to_datetime(load_20['Time stamp'], format = "%d.%m.%Y %H:%M:%S")
load_20.set_index('Time stamp', inplace = True)
load_20['LG 11'].plot()

# %%
load_30_n=(load_30-load_30.min())/(load_30.max()-load_30.min())
ax = load_30_n[load_30_n.columns[10:15]].plot(legend=False)
ax.set_xlim(pd.Timestamp('2017-02-15'), pd.Timestamp('2017-02-16'))
ax.set_ylabel('Normalized power demand')
# Out:
# Text(0, 0.5, 'Normalized power demand')
